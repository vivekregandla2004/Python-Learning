# %% [markdown]
# # Day 1 -Basics of Python
# ## second Heading
# ### third Heading
# #### fourth heading
# ##### firth heading
# ###### sixth heading

# %% [markdown]
# ### Text Formating
#
# This is a Normal Text
#
# *This is an Italic Text*
#
# **This is an Bold Text**
#
# ***This is Bold and Italic***
#
# ~This is Stricke Through Text~

# %% [markdown]
# #### Unordered List
#
# -Item 1
# -Item 2
# -Item 3
# -Item 4
# -Item 5
#
# #### Ordered List
# 1. Point
# 2. Point 2
# 3. Point 3
# 4. Point 4

# %% [markdown]
# #### BlockQuotes
# >This is a Highligheted note or important point

# %% [markdown]
# #### Links
# [Social Prachar](https://socialprachar.com)

# %% [markdown]
# #### Horizontal Line
# ---

# %% [markdown]
# #### Collapsible Section
# <details><summary>CLick to expand</summary>this is a collapsible section</details>

# %% [markdown]
# #### Basic Syntax in Python
# - Syntax refers to the set of rules that define the combinationsof symbols
# - These are consider to be conrreclty structued programs in Language
#     - In Simple terms ,Syntax is about the correct arrangement of words and symbols in a code

# %%
## Case Sensitiviy -->Python is Case Sensitive
name="vivgod"
Name="VIV"
print(name)
print(Name)
# Out:
# vivgod
# VIV

# %% [markdown]
# #### Indentation
# - Indentation in python is used to define the strcuture and hierarchy of the code

# %%
### Python Uses Indentation to define the block of code  
### consistent use of spaces (commonly 4 ) or a tab space

age=32
if age>30:
    print("Age is greater than 30")
else:
    print("Age  is not greater than 30")
# Out:
# Age is greater than 30

# %%
### Line Continuation
### Use a BackSlach (\) to continue a statement to the nextline  
total=1+2+3+4+5+6\
+7+8+9
print(total)
# Out:
# 45

# %%
### Multiple Statements in a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %% [markdown]
# #### Semantica In Python
# It refers to the meaning or interpreataion of the symbols , characters, and commands in a language
# - It  is about what the code is supposed to do when it runs

# %%
age=22  ## Age  is an Integer
name="vivek" ##Name is a  String

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
### TYPE Inference

varaible=10
print(varaible)
# Out:
# 10

# %%
varaible=20

print(varaible)
# Out:
# 20

# %%
### code indentation

if True:
    print("1")
    if False:
        print("2")
    print("3")
print("4")
# Out:
# 1
# 3
# 4
